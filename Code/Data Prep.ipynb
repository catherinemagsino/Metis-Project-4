# %%
import pandas as pd

# %%
df_review = pd.read_csv('review.csv')

# %%
df_business = pd.read_csv('business.csv')

# %%
df_review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA  ujmEBvifdJM6h6RLv4wQIg
# 1  GJXCdrto3ASJOqKeVWPi6Q  yXQM5uF2jS6es16SJzNHfg  NZnhc2sEQy3RmzKTZnqtwQ
# 2  2TzJjDVDEuAW6MR5Vuc1ug  n6-Gk65cPZL6Uz8qRm3NYw  WTqjgwHlXbSFevF32_DJVw
# 3  yi0R0Ugj_xUx_Nek0-_Qig  dacAIZ6fTM6mqwW5uxkskg  ikCg8xy5JIg_NGPx-MSIDA
# 4  11a8sVPMUFtaC7_ABRkmtw  ssoyf2_x0EQMed6fgHeMyQ  b1b1eb3uo-w561D0ZfCEiQ
#
#    stars  useful  funny  cool  \
# 0    1.0       6      1     0
# 1    5.0       0      0     0
# 2    5.0       3      0     0
# 3    5.0       0      0     0
# 4    1.0       7      0     0
#
#                                                 text                 date
# 0  Total bill for this horrible service? Over $8G...  2013-05-07 04:34:36
# 1  I *adore* Travis at the Hard Rock's new Kelly ...  2017-01-14 21:30:33
# 2  I have to say that this office really has it t...  2016-11-09 20:09:03
# ...

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6685900 entries, 0 to 6685899
# Data columns (total 9 columns):
# review_id      object
# user_id        object
# business_id    object
# stars          float64
# useful         int64
# funny          int64
# cool           int64
# text           object
# date           object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 459.1+ MB

# %%
df_business.head()
# Out:
#               business_id                             name  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
#
#                           address         city state postal_code   latitude  \
# 0     2818 E Camino Acequia Drive      Phoenix    AZ       85016  33.522143
# 1            30 Eglinton Avenue W  Mississauga    ON     L5R 3E7  43.605499
# 2       10110 Johnston Rd, Ste 15    Charlotte    NC       28210  35.092564
# 3   15655 W Roosevelt St, Ste 237     Goodyear    AZ       85338  33.455613
# 4  4209 Stuart Andrew Blvd, Ste F    Charlotte    NC       28217  35.190012
#
#     longitude  stars  review_count  is_open  \
# 0 -112.018481    3.0             5        0
# 1  -79.652289    2.5           128        1
# ...

# %%
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192609 entries, 0 to 192608
# Data columns (total 14 columns):
# business_id     192609 non-null object
# name            192609 non-null object
# address         184927 non-null object
# city            192608 non-null object
# state           192609 non-null object
# postal_code     191950 non-null object
# latitude        192609 non-null float64
# longitude       192609 non-null float64
# stars           192609 non-null float64
# review_count    192609 non-null int64
# is_open         192609 non-null int64
# attributes      163773 non-null object
# categories      192127 non-null object
# hours           147779 non-null object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 20.6+ MB

# %%
df_business['state'].value_counts()
# Out:
# AZ     56686
# NV     36312
# ON     33412
# NC     14720
# OH     14697
# PA     11216
# QC      9219
# AB      8012
# WI      5154
# IL      1932
# SC      1162
# NY        22
# CA        19
# TX         6
# XGM        4
# FL         4
# WA         3
# CT         3
# AL         3
# VT         2
# VA         2
# GA         2
# NE         2
# AK         2
# XWY        2
# DUR        1
# XGL        1
# BC         1
# AR         1
# TN         1
# BAS        1
# CON        1
# DOW        1
# NM         1
# UT         1
# NJ         1
# Name: state, dtype: int64

# %%
Master_df=pd.merge(df_review,df_business,on="business_id",how="left")

# %%
Master_df.head(2)
# Out:
#                 review_id                 user_id             business_id  \
# 0  Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA  ujmEBvifdJM6h6RLv4wQIg
# 1  GJXCdrto3ASJOqKeVWPi6Q  yXQM5uF2jS6es16SJzNHfg  NZnhc2sEQy3RmzKTZnqtwQ
#
#    stars_x  useful  funny  cool  \
# 0      1.0       6      1     0
# 1      5.0       0      0     0
#
#                                                 text                 date  \
# 0  Total bill for this horrible service? Over $8G...  2013-05-07 04:34:36
# 1  I *adore* Travis at the Hard Rock's new Kelly ...  2017-01-14 21:30:33
#
#                                               name  ... state postal_code  \
# 0                            MountainView Hospital  ...    NV       89128
# 1  Kelly Cardenas Salon - Hard Rock Hotel & Casino  ...    NV       89169
#
#     latitude   longitude  stars_y  review_count  is_open  \
# 0  36.215546 -115.248798      2.5           238        1
# 1  36.110083 -115.153871      4.5            66        1
#
# ...

# %%
Master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6685900 entries, 0 to 6685899
# Data columns (total 22 columns):
# review_id       object
# user_id         object
# business_id     object
# stars_x         float64
# useful          int64
# funny           int64
# cool            int64
# text            object
# date            object
# name            object
# address         object
# city            object
# state           object
# postal_code     object
# latitude        float64
# longitude       float64
# stars_y         float64
# review_count    int64
# is_open         int64
# attributes      object
# categories      object
# hours           object
# dtypes: float64(4), int64(5), object(13)
# memory usage: 1.1+ GB

# %%
df_restaurants=Master_df[Master_df['categories'].str.contains('Restaurants', na = False)]

# %%
df_restaurants.head()
# Out:
#                  review_id                 user_id             business_id  \
# 3   yi0R0Ugj_xUx_Nek0-_Qig  dacAIZ6fTM6mqwW5uxkskg  ikCg8xy5JIg_NGPx-MSIDA
# 5   fdiNeiN_hoCxCMy2wTRW9g  w31MKYsNFMrjhWxxAb5wIw  eU_713ec6fTGNO4BegRaww
# 6   G7XHMxG0bx9oBJNECG4IFg  jlu4CztcSxrKx56ba1a5AQ  3fw2X5bZYeW9xCz_zGhOHg
# 7   8e9HxxLjjqc9ez5ezzN7iQ  d6xvYpyzcfbF_AZ8vMB7QA  zvO-PJCpNk4fgAVUnExYAA
# 10  kbtscdyz6lvrtGjD1quQTg  FIk4lQQu1eTe2EpzQ4xhBA  8mIrX_LrOnAqWsB5JrOojQ
#
#     stars_x  useful  funny  cool  \
# 3       5.0       0      0     0
# 5       4.0       0      0     0
# 6       3.0       5      4     5
# 7       1.0       3      1     1
# 10      4.0       0      0     0
#
#                                                  text                date  \
# 3   Went in for a lunch. Steak sandwich was delici... 2018-01-09 20:56:38
# 5   I'll be the first to admit that I was not exci... 2013-01-20 13:25:59
# 6   Tracy dessert had a big name in Hong Kong and ... 2016-05-07 01:21:02
# ...

# %%
df_restaurants['date'] = pd.to_datetime(df_restaurants['date'])
# Out:
# /Users/juliusmagsino/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4201684 entries, 3 to 6685899
# Data columns (total 22 columns):
# review_id       object
# user_id         object
# business_id     object
# stars_x         float64
# useful          int64
# funny           int64
# cool            int64
# text            object
# date            datetime64[ns]
# name            object
# address         object
# city            object
# state           object
# postal_code     object
# latitude        float64
# longitude       float64
# stars_y         float64
# review_count    int64
# is_open         int64
# attributes      object
# categories      object
# hours           object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(12)
# memory usage: 737.3+ MB

# %%
df_Mex_restaurants=df_restaurants[df_restaurants['categories'].str.contains('Mexican', na = False)]

# %%
df_Mex_restaurants.head()
# Out:
#                   review_id                 user_id             business_id  \
# 17   6BnQwlxRn7ZuWdzninM9sQ  JSrP-dUmLlwZiI7Dp3PQ2A  cHdJXLlKNWixBXpDwEGb_A
# 23   S337tATeouQJdoPYyir29w  2mxBNBeFrgDszqGS5tdEHA  d_L-rfS1vT3JMzgCUGtiow
# 43   j3vP8537KHvoXNHQIr3haA  Z_HE_KKT7N-WddPTzUQC7A  jScBTQtdAt-8RshaiBEHgw
# 63   CvJy7CdHJqsZNq22fUF7hA  DAssyKNnYBenf0s1uP5iRw  dInxwF8kXVdfLEGTIBRrSw
# 121  a6N51Ov3NEchmqsquNGtMA  qpYllTutvfoKvT5OEl7gGQ  HkbNItNrnXlNo59M0YyoMg
#
#      stars_x  useful  funny  cool  \
# 17       3.0       1      7     1
# 23       5.0       0      0     0
# 43       5.0       1      0     1
# 63       2.0       0      1     0
# 121      5.0       0      0     0
#
#                                                   text                date  \
# 17   I love chinese food and I love mexican food. W... 2015-04-01 16:30:00
# 23   Pick any meat on the planet and the chef will ... 2016-07-25 03:57:19
# ...

# %%
df_Mex_restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 403941 entries, 17 to 6685898
# Data columns (total 22 columns):
# review_id       403941 non-null object
# user_id         403941 non-null object
# business_id     403941 non-null object
# stars_x         403941 non-null float64
# useful          403941 non-null int64
# funny           403941 non-null int64
# cool            403941 non-null int64
# text            403940 non-null object
# date            403941 non-null datetime64[ns]
# name            403941 non-null object
# address         403270 non-null object
# city            403941 non-null object
# state           403941 non-null object
# postal_code     403818 non-null object
# latitude        403941 non-null float64
# longitude       403941 non-null float64
# stars_y         403941 non-null float64
# review_count    403941 non-null int64
# is_open         403941 non-null int64
# attributes      402526 non-null object
# categories      403941 non-null object
# ...

# %%
df_NV_restaurants=df_restaurants[df_restaurants['state'].str.contains('NV', na = False)]

# %%
df_NV_restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1391673 entries, 10 to 6685899
# Data columns (total 22 columns):
# review_id       1391673 non-null object
# user_id         1391673 non-null object
# business_id     1391673 non-null object
# stars_x         1391673 non-null float64
# useful          1391673 non-null int64
# funny           1391673 non-null int64
# cool            1391673 non-null int64
# text            1391672 non-null object
# date            1391673 non-null datetime64[ns]
# name            1391673 non-null object
# address         1388989 non-null object
# city            1391673 non-null object
# state           1391673 non-null object
# postal_code     1391441 non-null object
# latitude        1391673 non-null float64
# longitude       1391673 non-null float64
# stars_y         1391673 non-null float64
# review_count    1391673 non-null int64
# is_open         1391673 non-null int64
# attributes      1387914 non-null object
# ...

# %%
df_NV_restaurants['city'].value_counts()
# Out:
# Las Vegas                1242697
# Henderson                 112874
# North Las Vegas            25336
# Boulder City                5882
# Spring Valley               1508
# Summerlin                    659
# South Las Vegas              620
# Las  Vegas                   444
# Blue Diamond                 424
# N. Las Vegas                 319
# Enterprise                   291
# LasVegas                     248
# Paradise                     116
# N Las Vegas                   92
# Nellis AFB                    59
# NELLIS AFB                    35
# LAS VEGAS                     21
# Green Valley                  14
# Pahrump                       12
# Nellis Air Force Base         10
# Sunrise Manor                  6
# Summerlin South                3
# Clark                          3
# Name: city, dtype: int64

# %%
df_NV_Mex_restaurants=df_NV_restaurants[df_NV_restaurants['categories'].str.contains('Mexican', na = False)]

# %%
df_NV_Mex_restaurants['business_id'].nunique()
# Out:
# 1016

# %%
df_NV_Mex_restaurants['business_id'].value_counts()
# Out:
# XZbuPXdyA0ZtTu3AzqtQhg    3339
# RwMLuOkImBIqqYj4SSKSPg    3283
# JDZ6_yycNQFTpUZzLIKHUg    2801
# QXV3L_QFGj8r6nWX2kS2hA    2455
# SVGApDPNdpFlEjwRQThCxA    1713
#                           ...
# sLTvF9FEpFR021_GVqjVog       3
# O2lgRDn64eAAd36goQySlw       3
# OwCviWV-WcPRFcYYesZHiQ       3
# H4TksVu70WQzg_BNV9QNJA       3
# Opufpwe4jaf--LtDZ_AHiw       3
# Name: business_id, Length: 1016, dtype: int64

# %%
df_NV_Mex_restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129659 entries, 23 to 6685898
# Data columns (total 22 columns):
# review_id       129659 non-null object
# user_id         129659 non-null object
# business_id     129659 non-null object
# stars_x         129659 non-null float64
# useful          129659 non-null int64
# funny           129659 non-null int64
# cool            129659 non-null int64
# text            129658 non-null object
# date            129659 non-null datetime64[ns]
# name            129659 non-null object
# address         129370 non-null object
# city            129659 non-null object
# state           129659 non-null object
# postal_code     129619 non-null object
# latitude        129659 non-null float64
# longitude       129659 non-null float64
# stars_y         129659 non-null float64
# review_count    129659 non-null int64
# is_open         129659 non-null int64
# attributes      129099 non-null object
# categories      129659 non-null object
# ...

# %%
df_NV_Mex_restaurants.head()
# Out:
#                   review_id                 user_id             business_id  \
# 23   S337tATeouQJdoPYyir29w  2mxBNBeFrgDszqGS5tdEHA  d_L-rfS1vT3JMzgCUGtiow
# 43   j3vP8537KHvoXNHQIr3haA  Z_HE_KKT7N-WddPTzUQC7A  jScBTQtdAt-8RshaiBEHgw
# 141  EedJ77WTwkytYhAR-PVMKQ  piYjHlLZQCtg9Q1QT0Lvbw  gOOfBSBZlffCkQ7dr7cpdw
# 142  kN7QMpXNT38NeeesQ6zYUQ  U6tZwpRVjUfx-fwDbMAlPA  lVfZ2AaYRYHCFenUMQna8g
# 187  LQ4seKEnmMK5PYKtFcaT3A  9SqPSd2HnDJIM3v4_j9LYA  SVGApDPNdpFlEjwRQThCxA
#
#      stars_x  useful  funny  cool  \
# 23       5.0       0      0     0
# 43       5.0       1      0     1
# 141      5.0       0      0     0
# 142      5.0       0      2     0
# 187      5.0       0      0     0
#
#                                                   text                date  \
# 23   Pick any meat on the planet and the chef will ... 2016-07-25 03:57:19
# 43   Party of 3 ordered the fish tacos, pork belly ... 2018-05-28 20:56:05
# ...

# %%
df_NV_Mex_restaurants['stars_x'].value_counts()
# Out:
# 5.0    57302
# 4.0    28057
# 1.0    17703
# 3.0    14982
# 2.0    11615
# Name: stars_x, dtype: int64

# %%
df_NV_Mex_restaurants.to_csv('df_NV_Mex_restaurants.csv',index=False)
